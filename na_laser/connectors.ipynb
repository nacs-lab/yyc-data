# %% [markdown]
# # Controller, Cable, Laser pin out of the TimeBase lasers

# %% [markdown]
# ## LD-1001 controller output
# * Connector type
#
#     15-pin D-sub
#
# * Pin out
#     * 1: **TS1 TEC+**
#     * 2: **TS1 TEC-**
#     * 4: **TS2: Heater**
#     * 5: **TS2: Heater**
#     * 7: **LD+ (anode)**
#     * 9: **TS1: Thermistor**
#     * 10: **TS1: Thermistor**
#     * 11: **TS2: Thermistor**
#     * 12: **TS2: Thermistor**
#     * 14: **LD- (cathode)**

# %% [markdown]
# ## Cables
# 1. MOT laser
#     * Controller side colors
#         * 1: **Brown + Brown-Green**
#         * 2: **Green + White-Green**
#         * 3: _**Yellow**_
#         * 4: _**NC**_
#         * 5: _**NC**_
#         * 6: _**Pink**_
#         * 7: **Red + Red-Blue**
#         * 8: **Purple**
#         * 9: **White**
#         * 10: **Pink-Grey**
#         * 11: _**NC**_
#         * 12: _**NC**_
#         * 13: _**Black**_
#         * 14: **Blue + Yellow-Brown**
#         * 15: _**Grey**_
#     * Laser side colors
#         * A: **Red + Red-Blue**
#         * B: **Green + White-Green**
#         * C: **Brown + Brown-Green**
#         * D: **White**
#         * E: **Pink-Grey**
#         * F: **NC**
#         * G: **Black**
#         * H: **Grey**
#         * J: **Pink**
#         * K: **Blue + Yellow-Brown**
#         * L: **Purple**
#         * M: **Yellow**
# 2. Raman laser
#     * Controller side colors
#         * 1: **Brown + Brown-Green**
#         * 2: **Green + White-Green**
#         * 3: _**NC**_
#         * 4: _**Grey**_
#         * 5: _**Black**_
#         * 6: _**NC**_
#         * 7: **Red + Red-Blue**
#         * 8: **Purple**
#         * 9: **White**
#         * 10: **Pink-Grey**
#         * 11: _**Pink**_
#         * 12: _**Yellow**_
#         * 13: _**NC**_
#         * 14: **Blue + Yellow-Brown**
#         * 15: _**NC**_
#     * Laser side colors
#         * A: **Red + Red-Blue**
#         * B: **Green + White-Green**
#         * C: **Brown + Brown-Green**
#         * D: **White**
#         * E: **Pink-Grey**
#         * F: **NC**
#         * G: **Black**
#         * H: **Grey**
#         * J: **Pink**
#         * K: **Blue + Yellow-Brown**
#         * L: **Purple**
#         * M: **Yellow**

# %% [markdown]
# ## Laser input
# * Connector type
#     * Manufacturer part number: `C091 31N012 200 2`
#     * DigiKey part number: `361-1302-ND`
# * MOT laser (derived from the pin out of the controller and cable)
#     * A: **LD+ (anode)**
#     * B: **TS1 TEC-**
#     * C: **TS1 TEC+**
#     * D: **TS1: Thermistor**
#     * E: **TS1: Thermistor**
#     * F: **NC**
#     * G: _**-**_
#     * H: _**-**_
#     * J: _**-**_
#     * K: **LD- (cathode)**
#     * L: **-**
#     * M: _**-**_
# * Raman laser (derived from the pin out of the controller and cable)
#     * A: **LD+ (anode)**
#     * B: **TS1 TEC-**
#     * C: **TS1 TEC+**
#     * D: **TS1: Thermistor**
#     * E: **TS1: Thermistor**
#     * F: **NC**
#     * G: _**TS2: Heater**_
#     * H: _**TS2: Heater**_
#     * J: _**TS2: Thermistor**_
#     * K: **LD- (cathode)**
#     * L: **-**
#     * M: _**TS2: Thermistor**_

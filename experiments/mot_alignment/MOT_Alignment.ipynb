# %%
include("beamage.jl")
# Out:
# read_beamage_txt (generic function with 2 methods)

# %%
cs_far = read_beamage_txt("data/Cs_far0.txt")
cs_far_small = read_beamage_txt("data/Cs_far-small0.txt")
na_far = read_beamage_txt("data/Na_far0.txt")
na_far_small = read_beamage_txt("data/Na_far-small0.txt");

# %%
using PyPlot

# %%
imshow(cs_far')
gca()[:set_aspect]("equal")
savefig("img/Cs_far0.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efd34559f98>)

# %%
imshow(na_far')
gca()[:set_aspect]("equal")
savefig("img/Na_far0.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efd231d2908>)

# %%
imshow(cs_far_small')
gca()[:set_aspect]("equal")
savefig("img/Cs_far-small0.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efd22143048>)

# %%
imshow(na_far_small')
gca()[:set_aspect]("equal")
savefig("img/Na_far0-small.png")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7efd231d2dd8>)

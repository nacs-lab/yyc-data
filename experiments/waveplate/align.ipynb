# %%
include("waveplate.jl")
# Out:
# plotSingleFile (generic function with 1 method)

# %%
plotFileFit(getFileInfo("589_2/589_0_0_origin"))
plotFileFit(getFileInfo("589_2/589_0_0_align"))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ffdc0c22320>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ffdc0bc8160>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7ffdc0b36da0>

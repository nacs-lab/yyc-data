# %% [markdown]
# # DDS Noise

# %% [markdown]
# ## Test before closing the box
#
# All channels output $11.8$ to $12$dBm at $100$MHz with amplitude $1$.
#
# Noise floors are not higher than $-45$dBm.
#
# Second order harmonics are around $-30$ to $-25$dBm. Third orders are too small to see.

# %% [markdown]
# ## Test after closing the box (top panel) (WIP)
#
# ### Single Channel Performance
#
# Frequencies (MHz) planning to test
#
# $100$, $250$, $450$ (close to $\dfrac18$ clock $437.5$MHz), $880$ (close to $\dfrac14$ clock frequency $875$MHz, also the frequency we need for Sodium hyperfine transition)
#
# All power in dBm unless otherwise noted.
#
# Noise floors are measured when the DDS is outputting $amp=1$ at $100MHz$ (see image below).
#
# 1. Channel $0$
#     * Noise floor: $<-70$
#     * $880$MHz: $-56$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-25$
#         2. Amp $0.1$
#             * Output: $-8$
#             * 2nd: Too small
#             * 5th: $-53$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $10$
#             * 2nd: $-26$
#             * 3rd: $-42$
#         2. Amp $0.1$
#             * Output: $-10$
#             * 3rd: $-51$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $10.5$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-9.1$
#             * Many small peaks: $-60$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9$
#             * 2nd: $-35$
#             * $860$MHz: $-46$
#             * $1740$MHz: $-40$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: Too small
#             * $860$MHz: $-54$
#             * $900$MHz: $-50$
#             * Many other around $880$MHz, $20$MHz apart: $<-60$
# 2. Channel $1$
#     * Noise floor: $<-70$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#             * 3rd: $<-42$
#         2. Amp $0.1$
#             * Output: $-7.8$
#             * 2nd: $<-60$
#             * 3rd: $<-60$
#             * 5th: $-52$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9$
#             * 2nd: $-28$
#             * 3rd: $<-44$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $<-60$
#             * 3rd: $-52$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $10$
#             * 2nd: $-33$
#             * 3rd: $<-40$
#         2. Amp $0.1$
#             * Output: $-10$
#             * 2nd: $<-60$
#             * 3rd: $-52$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8$
#             * 2nd: $-40$
#             * $2620MHz$: $-20$
#         2. Amp $0.1$
#             * Output: $-12$
#             * 2nd: $<-70$
#             * 3rd: $<-70$
#             * $2620MHz$: $-40$
#             * $860$MHz: $-53$
#             * $900$MHz: $-51$
#             * Other: $<-70$
# 3. Channel $2$
#     * Noise floor: $<-70$
#     * $880$MHz: $-56$
#     * $437$MHz: $-63$
#     1. $100$MHz
#         1. Amp $1$
#             * Screenshot of the spectrum analyser with $0$ attenuation when the channel is outputting $amp=1$ at $100$MHz
#                 ![Higher Harmonics](100MHz_Amp1_CH2.jpg)
#                 The peaks in the picture might be artifacts when the spectrum analyzer is over-driven.
#             * Output: $12$
#             * 2nd: $-30$
#             * 3rd: $-40$
#         2. Amp $0.1$
#             * Output: $-8$
#             * 2nd: $<-60$
#             * 3rd: $<-60$
#             * 5th: $-55$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $8.6$
#             * 2nd: $-27$
#             * 3rd: $-40$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $-62$
#             * 3rd: $-56$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $10$
#             * 2nd: $-31$
#             * 3rd: $-41$
#         2. Amp $0.1$
#             * Output: $-10$
#             * 2nd: $-60$
#             * 3rd: $-58$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8.3$
#             * 2nd: $-40$
#             * $860$MHz: $-48$
#             * $1740$MHz: $-40$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $-60$
#             * $860$MHz: $-57$
#             * $900$MHz: $-55$
#             * $2620$MHz: $-40$
# 4. Channel $3$
#     * Noise floor: $<-70$
#     * $880$MHz: $-56$
#     * $437$MHz: $-65$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#             * 3rd: $-35$
#         2. Amp $0.1$
#             * Output: $-8.2$
#             * 2nd: $-60$
#             * 3rd: $-58$
#             * 5th: $-51$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $8.8$
#             * 2nd: $-27$
#             * 3rd: $-40$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $-62$
#             * 3rd: $-51$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $10$
#             * 2nd: $-32$
#             * 3rd: $-41$
#         2. Amp $0.1$
#             * Output: $-10$
#             * 2nd: $<-61$
#             * 3rd: $<-52$
#             * $1250$MHz: $-49$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8.4$
#             * 2nd: $-45$
#             * $860$MHz: $-45$
#             * $1740$MHz: $-39$
#             * $2640$MHz: $-20$
#         2. Amp $0.1$
#             * Output: $-11.5$
#             * 2nd: $-61$
#             * $860$MHz: $-52$
#             * $900$MHz: $-50$
#             * $980$MHz: $-63$
#             * $1740$MHz: $-63$
#             * $2620$MHz: $-40$
# 5. Channel $4$
#     * Noise floor: $<-70$
#     * $880$MHz: $-57$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#             * 3rd: $-40$
#         2. Amp $0.1$
#             * Output: $-8.7$
#             * 2nd: $-64$
#             * 3rd: $-63$
#             * 5th: $-54$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $7.9$
#             * 2nd: $-27$
#             * 3rd: $-41$
#         2. Amp $0.1$
#             * Output: $-12$
#             * 2nd: $-64$
#             * 3rd: $-57$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $9.4$
#             * 2nd: $-31$
#             * 3rd: $-43$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $-64$
#             * 3rd: $-58$
#             * $1250$MHz: $-51$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8.4$
#             * 2nd: $-48$
#             * 3rd: $-51$
#             * $860$MHz: $-46$
#             * $1740$MHz: $-39$
#             * $2640$MHz: $-20$
#         2. Amp $0.1$
#             * Output: $-11.5$
#             * 2nd: $-$
#             * $840$MHz: $-64$
#             * $860$MHz: $-56$
#             * $900$MHz: $-52$
#             * $980$MHz: $-62$
#             * $1740$MHz: $-70$
#             * $2620$MHz: $-39$
# 6. Channel $5$
#     * Noise floor: $<70$
#     * $880$MHz: $-60$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
#         2. Amp $0.1$
#             * Output: $-$
#             * 2nd: $-$
#             * 3rd: $-$
#             * 5th: $-$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
#             * 3rd: $-$
#         2. Amp $0.1$
#             * Output: $-$
#             * 2nd: $-$
#             * 3rd: $-$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
#             * 3rd: $-$
#         2. Amp $0.1$
#             * Output: $-$
#             * 2nd: $-$
#             * 3rd: $-$
#             * $1250$MHz: $-$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
#             * $860$MHz: $-$
#             * $1740$MHz: $-$
#             * $2640$MHz: $-$
#         2. Amp $0.1$
#             * Output: $-$
#             * 2nd: $-$
#             * $860$MHz: $-$
#             * $900$MHz: $-$
#             * $980$MHz: $-$
#             * $1740$MHz: $-$
#             * $2620$MHz: $-$
# 7. Channel $6$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 8. Channel $7$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 9. Channel $8$
#     * This board used to be noisy
#     * Noise floor: $<-70$
#     * $880$MHz: $-64$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-28$
#             * 3rd: $-40$
# 10. Channel $9$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 11. Channel $10$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 12. Channel $11$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 13. Channel $12$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 14. Channel $13$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 15. Channel $14$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 16. Channel $15$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 17. Channel $16$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 18. Channel $17$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 19. Channel $18$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 20. Channel $19$
#     * Noise floor: $<-$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $.$
#             * 2nd: $-$
# 21. Channel $20$
#     * Noise floor: $<-70$
#     * **VERY NOISY** clock-like peaks get into the output and produce a comb-like spectrum. The repetition rate of the pulses depends on the frequency to be output.
#       Similar effect have been seen on other channels (Current channel 8, board 20) at specific frequencies (but it happens to this channel on all frequency)
# 22. Channel $21$
#     * Noise floor: $<-70$
#     * $880$MHz: $-$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.0$
#             * 2nd: $-27$
#             * 3rd: $-44$
#         2. Amp $0.1$
#             * Output: $-8$
#             * 2nd: $-64$
#             * 3rd: $-62$
#             * 5th: $-55$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $8.7$
#             * 2nd: $-27$
#             * 3rd: $-43$
#         2. Amp $0.1$
#             * Output: $-11$
#             * 2nd: $-64$
#             * 3rd: $-55$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $10.4$
#             * 2nd: $-32$
#             * 3rd: $-44$
#         2. Amp $0.1$
#             * Output: $-10.5$
#             * 2nd: $-60$
#             * 3rd: $-56$
#             * $1250$MHz: $-52$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8.4$
#             * 2nd: $-44$
#             * $860$MHz: $-44$
#             * $1740$MHz: $-38$
#             * $2640$MHz: $-18$
#         2. Amp $0.1$
#             * Output: $-11.5$
#             * 2nd: $-49$
#             * $860$MHz: $-55$
#             * $900$MHz: $-53.2$
#             * $980$MHz: $-64$
#             * $1740$MHz: $-55$
#             * $2620$MHz: $-38$

# %% [markdown]
# ### Crosstalk
# 1. Crosstalk (dB) when channel $10$ is at $800 MHz$ and amplitude $0.9$.
#     1. Measured in Channel $0$: $-50$
#     2. Measured in Channel $1$: $-44$
#     3. Measured in Channel $2$: $-46$
#     4. Measured in Channel $3$: $-49$
#     5. Measured in Channel $4$: $-44$
#     6. Measured in Channel $5$: $-38$
#     7. Measured in Channel $6$: $-$
#     8. Measured in Channel $7$: $-$
#     9. Measured in Channel $8$: $-$
#     10. Measured in Channel $9$: $-$
#     11. Measured in Channel $10$: $-$
#     12. Measured in Channel $12$: $-$
#     13. Measured in Channel $13$: $-$
#     14. Measured in Channel $14$: $-$
#     15. Measured in Channel $15$: $-$
#     16. Measured in Channel $16$: $-$
#     17. Measured in Channel $17$: $-$
#     18. Measured in Channel $18$: $-$
#     19. Measured in Channel $19$: $-$
#     20. Measured in Channel $20$: $-37.4$
#     21. Measured in Channel $21$: $-46$

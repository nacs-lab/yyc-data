# %% [markdown]
# # Test of the new DDS's for KRb

# %% [markdown]
# ## Test No. 1 to 12
#
# ### Single Channel Performance
#
# Frequencies (MHz) planning to test
#
# $100$, $880$
#
# All power in dBm unless otherwise noted.
#
# 1. Board $1$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.2$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 2. Board $2$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-25$
#         2. Amp $0.1$
#             * Output: $-8$
#             * 2nd: Too small
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 3. Board $3$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.3$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-7.5$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 4. Board $4$
#     Too high current from $3.3$V
# 5. Board $5$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 6. Board $6$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 7. Board $7$
#
#     The 60-pins connector was not soldered.
#
#     Test after fixing the solder:
#
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 8. Board $8$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $27$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 9. Board $9$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 10. Board $10$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 11. Board $11$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$
# 12. Board $12$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10$
#         2. Amp $0.1$
#             * Output: $-10$

# %% [markdown]
# # New boards (2015/6/10)
#
# **(No. 25 and No. 30 are burnt by the power supply overshot)**
#
# 1. Channel $13$
#     * $3.5$GHz: $-36$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.2$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7.5$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.3$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-10.6$
#             * 2nd: $-66$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.7$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-8.6$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.6$
#             * $860$MHz: $-48$
#         2. Amp $0.1$
#             * Output: $-10.1$
#             * $860$MHz: $-50$
#             * $900$MHz: $-49$
#
# 2. Channel $14$
#     * $3.5$GHz: $-38$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.3$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-7.5$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.2$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-10.6$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-8.3$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.5$
#         2. Amp $0.1$
#             * Output: $-9.6$
#             * $860$MHz: $-58$
#             * $900$MHz: $-52$
#
# 3. Channel $15$
#     * $3.5$GHz: $-36.5$
#     * Not recognized
#
# 4. Channel $16$
#     * $3.5$GHz: $-37$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $11.8$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.3$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-11$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.4$
#             * 2nd: $-30$
#         2. Amp $0.1$
#             * Output: $-8.3$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.7$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-54$
#             * $900$MHz: $-51$
#
# 5. Channel $17$
#     * $3.5$GHz: $-35$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-10$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.5$
#             * 2nd: $-25$
#         2. Amp $0.1$
#             * Output: $-10.3$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $10.2$
#         2. Amp $0.1$
#             * Output: $-9.7$
#
# 5. Channel $18$
#     * $3.5$GHz: $-36$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.5$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-10.6$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-30$
#         2. Amp $0.1$
#             * Output: $-8.2$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.9$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-54$
#             * $900$MHz: $-50$
#
# 6. Channel $19$
#     * $3.5$GHz: $-36$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.2$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-10.6$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-30$
#         2. Amp $0.1$
#             * Output: $-8.5$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.8$
#             * $860$MHz: $-49$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-56$
#             * $900$MHz: $-55$
#
# 7. Channel $20$
#     * $3.5$GHz: $-34$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $11.7$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $8.8$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-11$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11$
#             * 2nd: $-31$
#         2. Amp $0.1$
#             * Output: $-9$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $8.2$
#         2. Amp $0.1$
#             * Output: $-11.6$
#             * $860$MHz: $-60$
#             * $900$MHz: $-57.8$
#
# 8. Channel $21$
#     * $3.5$GHz: $-36$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7.8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.2$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-10.8$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.8$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-8.4$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.8$
#         2. Amp $0.1$
#             * Output: $-10.1$
#             * $860$MHz: $-60$
#             * $900$MHz: $-55$
#
# 9. Channel $22$
#     * $3.5$GHz: $-37$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $11.8$
#             * 2nd: $-28$
#         2. Amp $0.1$
#             * Output: $-7.7$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.3$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-10.6$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.6$
#             * 2nd: $-30$
#         2. Amp $0.1$
#             * Output: $-8.4$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.7$
#             * $860$MHz: $-52$
#         2. Amp $0.1$
#             * Output: $-10.2$
#             * $860$MHz: $-60$
#             *1$900$MHz: $-54$
#
# 10. Channel $23$
#     * Somehow broken (draw a lot of current from the power supply)
#
# 11. Channel $24$
#     * Didn't work at first but suddenly start working.
#     * $3.5$GHz: $-35$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7.8$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.3$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-11$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.7$
#             * 2nd: $-30$
#         2. Amp $0.1$
#             * Output: $-8.4$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.7$
#             * $860$MHz: $-49$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-60$
#             * $900$MHz: $-55$
#
# 12. Channel $26$
#     * $3.5$GHz: $-31$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7.7$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.3$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-10.5$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.8$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-8.3$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.8$
#             * $860$MHz: $-47$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-57$
#             * $900$MHz: $-52$
#
# 13. Channel $27$
#     * $3.5$GHz: $-39$
#     * Wrong echo
#     * Not recognized when retry
#
# 14. Channel $28$
#     * $3.5$GHz: $-37.6$
#     1. $100$MHz
#         1. Amp $1$
#             * Output: $12.2$
#             * 2nd: $-27$
#         2. Amp $0.1$
#             * Output: $-7.7$
#     2. $250$MHz
#         1. Amp $1$
#             * Output: $9.6$
#             * 2nd: $-26$
#         2. Amp $0.1$
#             * Output: $-10.4$
#     3. $450$MHz
#         1. Amp $1$
#             * Output: $11.9$
#             * 2nd: $-29$
#         2. Amp $0.1$
#             * Output: $-8.3$
#     4. $880$MHz
#         1. Amp $1$
#             * Output: $9.9$
#             * $860$MHz: $-54$
#         2. Amp $0.1$
#             * Output: $-10$
#             * $860$MHz: $-65$
#             * $900$MHz: $-56$
#
# 15. Channel $29$
#     * Draw too much current

# %% [markdown]
# # Controller, Cable, Laser pin out of the TimeBase lasers

# %% [markdown]
# ## LD-1001 controller output
# * Connector type
#
#     15-pin D-sub
#
# * Pin out
#     * 1: **TS1 TEC+**
#     * 2: **TS1 TEC-**
#     * 4: **TS2: Heater**
#     * 5: **TS2: Heater**
#     * 7: **LD+ (anode)**
#     * 9: **TS1: Thermistor**
#     * 10: **TS1: Thermistor**
#     * 11: **TS2: Thermistor**
#     * 12: **TS2: Thermistor**
#     * 14: **LD- (cathode)**

# %% [markdown]
# ## Cables
# 1. MOT laser
#     * Controller side colors
#         * 1: **Brown + Brown-Green**
#         * 2: **Green + White-Green**
#         * 3: _**Yellow**_
#         * 4: _**NC**_
#         * 5: _**NC**_
#         * 6: _**Pink**_
#         * 7: **Red + Red-Blue**
#         * 8: **Purple**
#         * 9: **White**
#         * 10: **Pink-Grey**
#         * 11: _**NC**_
#         * 12: _**NC**_
#         * 13: _**Black**_
#         * 14: **Blue + Yellow-Brown**
#         * 15: _**Grey**_
#     * Laser side colors
#         * A: **NC**
#         * B: **Black**
#         * C: **Grey**
#         * D: **Pink**
#         * E: **Blue + Yellow-Brown**
#         * F: **Red + Red-Blue**
#         * G: **Green + White-Green**
#         * H: **Brown + Brown-Green**
#         * J: **White**
#         * K: **Pink-Grey**
#         * L: **Yellow**
#         * M: **Purple**
# 2. Raman laser
#     * Controller side colors
#         * 1: **Brown + Brown-Green**
#         * 2: **Green + White-Green**
#         * 3: _**NC**_
#         * 4: _**Grey**_
#         * 5: _**Black**_
#         * 6: _**NC**_
#         * 7: **Red + Red-Blue**
#         * 8: **Purple**
#         * 9: **White**
#         * 10: **Pink-Grey**
#         * 11: _**Pink**_
#         * 12: _**Yellow**_
#         * 13: _**NC**_
#         * 14: **Blue + Yellow-Brown**
#         * 15: _**NC**_
#     * Laser side colors
#         * A: **NC**
#         * B: **Black**
#         * C: **Grey**
#         * D: **Pink**
#         * E: **Blue + Yellow-Brown**
#         * F: **Red + Red-Blue**
#         * G: **Green + White-Green**
#         * H: **Brown + Brown-Green**
#         * J: **White**
#         * K: **Pink-Grey**
#         * L: **Yellow**
#         * M: **Purple**

# %% [markdown]
# ## Laser input
# * Connector type
#     * Manufacturer part number: `C091 31N012 200 2`
#     * DigiKey part number: `361-1302-ND`
# * MOT laser (derived from the pin out of the controller and cable)
#     * A: **NC**
#     * B: _**-**_
#     * C: _**-**_
#     * D: _**-**_
#     * E: **LD- (cathode)**
#     * F: **LD+ (anode)**
#     * G: **TS1 TEC-**
#     * H: **TS1 TEC+**
#     * J: **TS1: Thermistor**
#     * K: **TS1: Thermistor**
#     * L: _**-**_
#     * M: **-**
# * Raman laser (derived from the pin out of the controller and cable)
#     * A: **NC**
#     * B: _**TS2: Heater**_
#     * C: _**TS2: Heater**_
#     * D: _**TS2: Thermistor**_
#     * E: **LD- (cathode)**
#     * F: **LD+ (anode)**
#     * G: **TS1 TEC-**
#     * H: **TS1 TEC+**
#     * J: **TS1: Thermistor**
#     * K: **TS1: Thermistor**
#     * L: _**TS2: Thermistor**_
#     * M: **-**

# %% [markdown]
# ## Thorlab Temperature Controller 9 Pin output
#
# IIRC, Thorlabs and TimeBase use different conventions for TEC polarity.
#
# The connector from the controller (cable) is a female connector and we need to make a male connector in order to connect to it.
#
# * 1: **Status LED+**
# * 2: **Thermistor+**
# * 3: **Thermistor-, GND**
# * 4: _**TEC+**_
# * 5: _**TEC-, Status LED-**_
# * 6: **NC**
# * 7: **AD 590/592-, LM 135/335+**
# * 8: **LM 135/335-, GND**
# * 9: **AD 590/592+, LM 135/335+**

# %% [markdown]
# ## Thorlab Current Controller output
#
# For connecting Timebase laser, we short the interlock (between 1 and 5) and use the Cathode ground mode (connect the cathode to Laser Diode GND and the anode to Laser Diode Anode).
#
# The cable is male on both side. If we are using the thorlabs cable that comes with the controller, we need to make a female connector.
#
# * 1: **Interlock, Status ON/OFF**
# * 2: **Photodiode**
# * 3: **Laser Diode GND**
# * 4: **Photodiode**
# * 5: **GND (for 1)**
# * 6: **Voltage Measurement Laser Diode Cathode**
# * 7: **Laser Diode Cathode**
# * 8: **Laser Diode Anode**
# * 9: **Voltage Measurement Laser Diode Anode**
